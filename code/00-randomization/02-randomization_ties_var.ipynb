# %%
import pandas as pd
import numpy as np
from tweetple import TweetPle
import sys
sys.path.insert(0, '../../src/utils')
from funcs import *
from tqdm import tqdm
sys.path.insert(0, '../../src/utils')
from general import *


followers_sa = pd.read_parquet('../../data/randomization/SA/influencers/followers_ties.parquet')
followers_ke = pd.read_parquet('../../data/randomization/KE/influencers/followers_ties.parquet')

followers_grouped_n_sa = followers_sa[['influencer_id', 'follower_id']].groupby('influencer_id').count()
followers_grouped_n_sa.rename({'follower_id': 'followers'}, axis=1, inplace=True)

followers_grouped_sa = followers_sa.groupby('influencer_id').sum()
followers_grouped_sa = followers_grouped_sa.merge(followers_grouped_n_sa, on='influencer_id', how='left')
followers_grouped_sa = followers_grouped_sa[['followers','strong', 'weak']]
followers_grouped_sa['absent'] = followers_grouped_sa['followers'] - followers_grouped_sa['strong'] - followers_grouped_sa['weak']

followers_grouped_n = followers_ke[['influencer_id', 'follower_id']].groupby('influencer_id').count()
followers_grouped_n.rename({'follower_id': 'followers'}, axis=1, inplace=True)

followers_grouped_ke = followers_ke.groupby('influencer_id').sum()
followers_grouped_ke = followers_grouped_ke.merge(followers_grouped_n, on='influencer_id', how='left')

followers_grouped_ke = followers_grouped_ke[['followers','strong', 'weak']]
followers_grouped_ke['absent'] = followers_grouped_ke['followers'] - followers_grouped_ke['strong'] - followers_grouped_ke['weak']

followers_grouped_ke.rename(columns = {'followers':'followers',
                            'strong':'n_strong',
                            'weak':'n_weak',
                            'absent':'n_absent'}, inplace = True)
followers_grouped_sa.rename(columns = {'followers':'followers',
                            'strong':'n_strong',
                            'weak':'n_weak',
                            'absent':'n_absent'}, inplace = True)

followers_grouped_ke.to_parquet('../../data/randomization/KE/02-variables/variables_ties.parquet')
followers_grouped_sa.to_parquet('../../data/randomization/SA/02-variables/variables_ties.parquet')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_13760\105496000.py:18: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   followers_grouped_sa = followers_sa.groupby('influencer_id').sum()
# C:\Users\Dell\AppData\Local\Temp\ipykernel_13760\105496000.py:26: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   followers_grouped_ke = followers_ke.groupby('influencer_id').sum()

# %% [markdown]
# ## Batch 2: Not running because one file dissappeared: followers_ties_batch2

# %%
followers_sa = pd.read_parquet('../../data/randomization/SA/influencers/followers_ties_batch2.parquet')

followers_grouped_n_sa = followers_sa[['influencer_id', 'follower_id']].groupby('influencer_id').count()
followers_grouped_n_sa.rename({'follower_id': 'followers'}, axis=1, inplace=True)

followers_grouped_sa = followers_sa.groupby('influencer_id').sum()
followers_grouped_sa = followers_grouped_sa.merge(followers_grouped_n_sa, on='influencer_id', how='left')
followers_grouped_sa = followers_grouped_sa[['followers','strong', 'weak']]
followers_grouped_sa['absent'] = followers_grouped_sa['followers'] - followers_grouped_sa['strong'] - followers_grouped_sa['weak']

followers_grouped_sa.rename(columns = {'followers':'followers',
                            'strong':'n_strong',
                            'weak':'n_weak',
                            'absent':'n_absent'}, inplace = True)


followers_grouped_sa.to_parquet('../../data/randomization/SA/02-variables/variables_ties_batch2f.parquet')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_13760\976127890.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   followers_grouped_sa = followers_sa.groupby('influencer_id').sum()

# %%
# DOES NOT RUN NEED TO FIND AND RUN THE TIE CREATION:

followers_ke = pd.read_parquet('../../data/randomization/KE/influencers/followers_ties_batch2.parquet')

followers_grouped_n = followers_ke[['influencer_id', 'follower_id']].groupby('influencer_id').count()
followers_grouped_n.rename({'follower_id': 'followers'}, axis=1, inplace=True)

followers_grouped_ke = followers_ke.groupby('influencer_id').sum()
followers_grouped_ke = followers_grouped_ke.merge(followers_grouped_n, on='influencer_id', how='left')

followers_grouped_ke = followers_grouped_ke[['followers','strong', 'weak']]
followers_grouped_ke['absent'] = followers_grouped_ke['followers'] - followers_grouped_ke['strong'] - followers_grouped_ke['weak']

followers_grouped_ke.rename(columns = {'followers':'n_followers',
                            'strong':'n_strong',
                            'weak':'n_weak',
                            'absent':'n_absent'}, inplace = True)

followers_grouped_ke.to_parquet('../../data/randomization/KE/02-variables/variables_ties_batch2.parquet')
